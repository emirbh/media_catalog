# %%
import json
import pandas as pd

# %%
catalog_file = "/Users/emirbh/my_media/media_catalog.json"
with open(catalog_file, "r") as fd:
    catalog_data = json.load(fd)
df = pd.DataFrame(catalog_data)["entries"]

# %%
df.head()
# Out:
# 9c742a3054c1e371d3e1525b2775bc9a2e631bb45b018c85f739e3aa49eb2723    {'hash': '9c742a3054c1e371d3e1525b2775bc9a2e63...
# 976321ce187f1ade5cec94f86bcb435163491b92fce97470dd0cdaca77d5ceac    {'hash': '976321ce187f1ade5cec94f86bcb43516349...
# 72bf05e41847d8648cf40bd97b4a0e412f1539a960787cff0cdfffa97a9d1914    {'hash': '72bf05e41847d8648cf40bd97b4a0e412f15...
# 03bc47cbc0d18dc098140494edcaaea973c2e89451eb83b1d0b3dc1f6f03790f    {'hash': '03bc47cbc0d18dc098140494edcaaea973c2...
# 6ce9d05390d642856af9c9dcee766cfe1762c4969a33032f55d150a7b982b3f8    {'hash': '6ce9d05390d642856af9c9dcee766cfe1762...
# Name: entries, dtype: object

# %%
entries = df
